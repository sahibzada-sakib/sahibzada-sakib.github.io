# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Sakib\Downloads\Bangladessh.project1\SBAnational.csv')
df.sample(5)
# Out:
# C:\Users\Sakib\AppData\Local\Temp\ipykernel_7400\124105209.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r'C:\Users\Sakib\Downloads\Bangladessh.project1\SBAnational.csv')
#         LoanNr_ChkDgt                            Name  \
# 698873     7258094010          TAYLORED SKIN CARE LLC
# 242205     2708675009  PRECISION ACCOUNTING SOLUTIONS
# 86657      1645804001             S & S PRECAST, INC.
# 442876     4300643003        JANET L. HARRINGER, D.C.
# 674571     6909394006         MADRONA ENTERPRISES INC
#
#                                   City State    Zip  \
# 698873  MEREDITH (CENSUS NAME FOR MERE    NH   3253
# 242205                       TREMONTON    UT  84337
# 86657                          WINAMAC    IN  46996
# 442876                       LANCASTER    PA  17601
# 674571                         SEATTLE    WA  98122
#
#                                   Bank BankState   NAICS ApprovalDate  \
# ...

# %%
df.shape
# Out:
# (899164, 27)

# %%
null=df.isnull().sum()/df.shape[0]
null
# Out:
# LoanNr_ChkDgt        0.0
# Zip                  0.0
# NAICS                0.0
# ApprovalDate         0.0
# ApprovalFY           0.0
# Term                 0.0
# NoEmp                0.0
# CreateJob            0.0
# RetainedJob          0.0
# FranchiseCode        0.0
# UrbanRural           0.0
# DisbursementGross    0.0
# BalanceGross         0.0
# ChgOffPrinGr         0.0
# GrAppv               0.0
# SBA_Appv             0.0
# dtype: float64

# %%
total = df.isnull().sum().sort_values(ascending = False)
percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
loan_missing_value  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
loan_missing_value
# Out:
#                    Total  Percent
# LoanNr_ChkDgt          0      0.0
# Zip                    0      0.0
# NAICS                  0      0.0
# ApprovalDate           0      0.0
# ApprovalFY             0      0.0
# Term                   0      0.0
# NoEmp                  0      0.0
# CreateJob              0      0.0
# RetainedJob            0      0.0
# FranchiseCode          0      0.0
# UrbanRural             0      0.0
# DisbursementGross      0      0.0
# BalanceGross           0      0.0
# ChgOffPrinGr           0      0.0
# GrAppv                 0      0.0
# SBA_Appv               0      0.0

# %%
df.drop(columns='ChgOffDate', axis=1, inplace=True)

# %%
df.head()
# Out:
#    LoanNr_ChkDgt                           Name          City State    Zip  \
# 0     1000014003                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1     1000024006    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2     1000034009          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3     1000044001  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4     1000054004    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState   NAICS ApprovalDate ApprovalFY  \
# 0               FIFTH THIRD BANK        OH  451120    28-Feb-97       1997
# 1                1ST SOURCE BANK        IN  722410    28-Feb-97       1997
# 2        GRANT COUNTY STATE BANK        IN  621210    28-Feb-97       1997
# 3  1ST NATL BK & TR CO OF BROKEN        OK       0    28-Feb-97       1997
# 4        FLORIDA BUS. DEVEL CORP        FL       0    28-Feb-97       1997
#
# ...

# %%
df = df.dropna(axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899164 entries, 0 to 899163
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   LoanNr_ChkDgt      899164 non-null  int64
#  1   Zip                899164 non-null  int64
#  2   NAICS              899164 non-null  int64
#  3   ApprovalDate       899164 non-null  datetime64[ns]
#  4   ApprovalFY         899164 non-null  object
#  5   Term               899164 non-null  int64
#  6   NoEmp              899164 non-null  int64
#  7   CreateJob          899164 non-null  int64
#  8   RetainedJob        899164 non-null  int64
#  9   FranchiseCode      899164 non-null  int64
#  10  UrbanRural         899164 non-null  int64
#  11  DisbursementGross  899164 non-null  object
#  12  BalanceGross       899164 non-null  object
#  13  ChgOffPrinGr       899164 non-null  object
#  14  GrAppv             899164 non-null  object
# ...

# %%
df['ApprovalDate'] = pd.to_datetime(df['ApprovalDate'])
# Out:
# C:\Users\Sakib\AppData\Local\Temp\ipykernel_7400\1706828047.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['ApprovalDate'] = pd.to_datetime(df['ApprovalDate'])

# %%
df.columns
# Out:
# Index(['LoanNr_ChkDgt', 'Name', 'City', 'State', 'Zip', 'Bank', 'BankState',
#        'NAICS', 'ApprovalDate', 'ApprovalFY', 'Term', 'NoEmp', 'NewExist',
#        'CreateJob', 'RetainedJob', 'FranchiseCode', 'UrbanRural', 'RevLineCr',
#        'LowDoc', 'ChgOffDate', 'DisbursementDate', 'DisbursementGross',
#        'BalanceGross', 'MIS_Status', 'ChgOffPrinGr', 'GrAppv', 'SBA_Appv'],
#       dtype='object')

# %%
df['City'].value_counts()
# Out:
# City
# LOS ANGELES                       11558
# HOUSTON                           10247
# NEW YORK                           7846
# CHICAGO                            6036
# MIAMI                              5594
#                                   ...
# EL DORADO SPRINGS (ELDORADO SP        1
# HUNTINDON                             1
# LEBAHON                               1
# WILLOW RIVER                          1
# SO. OZONE PARK                        1
# Name: count, Length: 32581, dtype: int64

# %%
city_counts = df['City'].value_counts()
cities = city_counts[city_counts >= 100].index
cities.value_counts()
# Out:
# City
# LOS ANGELES        1
# KOKOMO             1
# DALTON             1
# BENSALEM           1
# PACOIMA            1
#                   ..
# DEER PARK          1
# LOCKPORT           1
# EAST PROVIDENCE    1
# ASHEVILLE          1
# BROUSSARD          1
# Name: count, Length: 1667, dtype: int64

# %%
sns.couplot(x='City')
# Out:
# C:\Users\Sakib\AppData\Local\Temp\ipykernel_7400\764603691.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x='City')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sns.distplot(x='City')
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:2458, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2455     a = x
#    2457 # Make a a 1-d float array
# -> 2458 a = np.asarray(a, float)
# ...
